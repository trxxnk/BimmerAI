# %%
import pandas as pd

# %%
data = pd.read_csv("../data/bmw_data.csv")
data
# Out:
#                                    Модель   Год  Пробег   Цена  \
# 0                         BMW 1 серия F40  2019  129000  16999
# 1     BMW 7 серия G12 (Long) · Рестайлинг  2019   35000  83777
# 2                         BMW 5 серия E39  1999  400000   3399
# 3          BMW 1 серия E81, E82, E88, E87  2005  370000   7200
# 4                 BMW X6 E71 · Рестайлинг  2012  149000  23450
# ...                                   ...   ...     ...    ...
# 2970                           BMW X6 E71  2011  277000  22290
# 2971                 BMW 5 серия F10, F11  2012  256000  23500
# 2972            BMW 4 серия F32, F33, F36  2013  268500  21500
# 2973        BMW 2 серия Active Tourer F45  2017  200000  13000
# 2974                      BMW 7 серия E65  2002  280000   6300
#
#                                        Описание
# 0           робот, 1,5 л, дизель, хэтчбек 5 дв.
# 1                 автомат, 3,0 л, дизель, седан
# 2                механика, 2,5 л, дизель, седан
# 3         автомат, 2,0 л, бензин, хэтчбек 5 дв.
# 4     автомат, 3,0 л, бензин, внедорожник 5 дв.
# ...                                         ...
# 2970  автомат, 3,0 л, дизель, внедорожник 5 дв.
# 2971              автомат, 3,0 л, дизель, седан
# 2972               автомат, 2,0 л, бензин, купе
# 2973           механика, 1,5 л, дизель, минивэн
# 2974              автомат, 3,6 л, бензин, седан
#
# [2975 rows x 5 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2975 entries, 0 to 2974
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Модель    2975 non-null   object
#  1   Год       2975 non-null   int64
#  2   Пробег    2975 non-null   int64
#  3   Цена      2975 non-null   int64
#  4   Описание  2975 non-null   object
# dtypes: int64(3), object(2)
# memory usage: 116.3+ KB

# %%
data.drop_duplicates(inplace=True)
data
# Out:
#                                    Модель   Год  Пробег   Цена  \
# 0                         BMW 1 серия F40  2019  129000  16999
# 1     BMW 7 серия G12 (Long) · Рестайлинг  2019   35000  83777
# 2                         BMW 5 серия E39  1999  400000   3399
# 3          BMW 1 серия E81, E82, E88, E87  2005  370000   7200
# 4                 BMW X6 E71 · Рестайлинг  2012  149000  23450
# ...                                   ...   ...     ...    ...
# 2970                           BMW X6 E71  2011  277000  22290
# 2971                 BMW 5 серия F10, F11  2012  256000  23500
# 2972            BMW 4 серия F32, F33, F36  2013  268500  21500
# 2973        BMW 2 серия Active Tourer F45  2017  200000  13000
# 2974                      BMW 7 серия E65  2002  280000   6300
#
#                                        Описание
# 0           робот, 1,5 л, дизель, хэтчбек 5 дв.
# 1                 автомат, 3,0 л, дизель, седан
# 2                механика, 2,5 л, дизель, седан
# 3         автомат, 2,0 л, бензин, хэтчбек 5 дв.
# 4     автомат, 3,0 л, бензин, внедорожник 5 дв.
# ...                                         ...
# 2970  автомат, 3,0 л, дизель, внедорожник 5 дв.
# 2971              автомат, 3,0 л, дизель, седан
# 2972               автомат, 2,0 л, бензин, купе
# 2973           механика, 1,5 л, дизель, минивэн
# 2974              автомат, 3,6 л, бензин, седан
#
# [2939 rows x 5 columns]

# %%
description_columns = ['Коробка', 'Объем', 'Топливо', 'Кузов', 'Доп. информация']
data[description_columns] = data['Описание'].str.split(', ', expand=True)
data.drop(columns=['Описание'], inplace=True)
data
# Out:
#                                    Модель   Год  Пробег   Цена   Коробка  \
# 0                         BMW 1 серия F40  2019  129000  16999     робот
# 1     BMW 7 серия G12 (Long) · Рестайлинг  2019   35000  83777   автомат
# 2                         BMW 5 серия E39  1999  400000   3399  механика
# 3          BMW 1 серия E81, E82, E88, E87  2005  370000   7200   автомат
# 4                 BMW X6 E71 · Рестайлинг  2012  149000  23450   автомат
# ...                                   ...   ...     ...    ...       ...
# 2970                           BMW X6 E71  2011  277000  22290   автомат
# 2971                 BMW 5 серия F10, F11  2012  256000  23500   автомат
# 2972            BMW 4 серия F32, F33, F36  2013  268500  21500   автомат
# 2973        BMW 2 серия Active Tourer F45  2017  200000  13000  механика
# 2974                      BMW 7 серия E65  2002  280000   6300   автомат
#
#       Объем Топливо              Кузов Доп. информация
# 0     1,5 л  дизель      хэтчбек 5 дв.            None
# 1     3,0 л  дизель              седан            None
# 2     2,5 л  дизель              седан            None
# 3     2,0 л  бензин      хэтчбек 5 дв.            None
# 4     3,0 л  бензин  внедорожник 5 дв.            None
# ...     ...     ...                ...             ...
# 2970  3,0 л  дизель  внедорожник 5 дв.            None
# 2971  3,0 л  дизель              седан            None
# 2972  2,0 л  бензин               купе            None
# 2973  1,5 л  дизель            минивэн            None
# 2974  3,6 л  бензин              седан            None
#
# [2939 rows x 9 columns]

# %%
data[~data['Доп. информация'].isna()]
# Out:
#                        Модель   Год  Пробег   Цена  Коробка  Объем  \
# 2844  BMW i3 I01 · Рестайлинг  2018   80363  15775  автомат  0,7 л
#
#               Топливо          Кузов    Доп. информация
# 2844  бензин (гибрид)  хэтчбек 5 дв.  запас хода 220 км

# %%
data.drop(columns=['Доп. информация'], inplace=True)
data
# Out:
#                                    Модель   Год  Пробег   Цена   Коробка  \
# 0                         BMW 1 серия F40  2019  129000  16999     робот
# 1     BMW 7 серия G12 (Long) · Рестайлинг  2019   35000  83777   автомат
# 2                         BMW 5 серия E39  1999  400000   3399  механика
# 3          BMW 1 серия E81, E82, E88, E87  2005  370000   7200   автомат
# 4                 BMW X6 E71 · Рестайлинг  2012  149000  23450   автомат
# ...                                   ...   ...     ...    ...       ...
# 2970                           BMW X6 E71  2011  277000  22290   автомат
# 2971                 BMW 5 серия F10, F11  2012  256000  23500   автомат
# 2972            BMW 4 серия F32, F33, F36  2013  268500  21500   автомат
# 2973        BMW 2 серия Active Tourer F45  2017  200000  13000  механика
# 2974                      BMW 7 серия E65  2002  280000   6300   автомат
#
#       Объем Топливо              Кузов
# 0     1,5 л  дизель      хэтчбек 5 дв.
# 1     3,0 л  дизель              седан
# 2     2,5 л  дизель              седан
# 3     2,0 л  бензин      хэтчбек 5 дв.
# 4     3,0 л  бензин  внедорожник 5 дв.
# ...     ...     ...                ...
# 2970  3,0 л  дизель  внедорожник 5 дв.
# 2971  3,0 л  дизель              седан
# 2972  2,0 л  бензин               купе
# 2973  1,5 л  дизель            минивэн
# 2974  3,6 л  бензин              седан
#
# [2939 rows x 8 columns]

# %%
data['Модель'].value_counts()
# Out:
# Модель
# BMW 5 серия E39 · Рестайлинг             131
# BMW 5 серия E39                          130
# BMW 5 серия G30, G31                     111
# BMW X3 G01                               101
# BMW 3 серия G20, G21                      99
#                                         ...
# BMW M6 E63, E64                            1
# BMW 1 серия E82, E88 · 2-й рестайлинг      1
# BMW 6 серия E24                            1
# BMW M3 F80                                 1
# BMW XM                                     1
# Name: count, Length: 140, dtype: int64

# %%
data.groupby('Модель').mean(numeric_only=True).sort_values(by='Цена', ascending=False).round()
# Out:
#                                     Год    Пробег      Цена
# Модель
# BMW XM                           2023.0   26000.0  196000.0
# BMW X5 G05 · Рестайлинг, 7 мест  2024.0   10400.0  149000.0
# BMW X7 I · Рестайлинг, 7 мест    2024.0   13043.0  137011.0
# BMW 7 серия G70                  2023.0   16933.0  126333.0
# BMW i7                           2022.0   40531.0  124467.0
# ...                                 ...       ...       ...
# BMW 3 серия E21                  1980.0  226500.0    3450.0
# BMW 7 серия E32                  1989.0  467483.0    3430.0
# BMW 3 серия E36                  1996.0  381537.0    2839.0
# BMW 5 серия E34                  1993.0  438039.0    2754.0
# BMW 5 серия E28                  1986.0  275000.0    1850.0
#
# [140 rows x 3 columns]
