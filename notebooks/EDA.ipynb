# %%
import pandas as pd

# %%
data = pd.read_csv("../data/bmw_prices.csv")
data
# Out:
#                              Модель   Год  Пробег   Цена  \
# 0    BMW 1 серия E81, E82, E88, E87  2005  370000   7200
# 1           BMW X6 E71 · Рестайлинг  2012  149000  23450
# 2            BMW 7 серия F02 (Long)  2010  225000  17900
# 3           BMW X3 G01 · Рестайлинг  2021    7440  75900
# 4         BMW 8 серия G14, G15, G16  2021   87000  62350
# ..                              ...   ...     ...    ...
# 245                 BMW 5 серия E39  1999  999999   3500
# 246            BMW 5 серия F10, F11  2012  258000  17000
# 247                 BMW 3 серия E46  2001  520000   3850
# 248                 BMW 5 серия E39  1999  400000   3499
# 249         BMW X5 E70 · Рестайлинг  2010  285000  22500
#
#                                       Описание
# 0        автомат, 2,0 л, бензин, хэтчбек 5 дв.
# 1    автомат, 3,0 л, бензин, внедорожник 5 дв.
# 2                автомат, 4,4 л, бензин, седан
# 3    автомат, 2,0 л, дизель, внедорожник 5 дв.
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Модель    250 non-null    object
#  1   Год       250 non-null    int64
#  2   Пробег    250 non-null    int64
#  3   Цена      250 non-null    int64
#  4   Описание  250 non-null    object
# dtypes: int64(3), object(2)
# memory usage: 9.9+ KB
